# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r"E:\data\tmdb_movies_backup.csv")
df2 = pd.read_csv(r"E:\data\tmdb_movies_extra_backup.csv")

# %%
df1.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86280 entries, 0 to 86279
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      86280 non-null  int64
#  1   title         86280 non-null  object
#  2   overview      85996 non-null  object
#  3   genres        86280 non-null  object
#  4   keywords      86280 non-null  object
#  5   cast          86280 non-null  object
#  6   director      85752 non-null  object
#  7   release_date  86246 non-null  object
#  8   runtime       86280 non-null  int64
#  9   popularity    86280 non-null  float64
#  10  poster_url    85121 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 7.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86276 entries, 0 to 86275
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       86276 non-null  int64
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(5)

# %%
df1.drop_duplicates(inplace=True)

# %%
df2.duplicated().sum()
# Out:
# np.int64(3)

# %%
df2.drop_duplicates(inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86275 entries, 0 to 86279
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      86275 non-null  int64
#  1   title         86275 non-null  object
#  2   overview      85991 non-null  object
#  3   genres        86275 non-null  object
#  4   keywords      86275 non-null  object
#  5   cast          86275 non-null  object
#  6   director      85747 non-null  object
#  7   release_date  86241 non-null  object
#  8   runtime       86275 non-null  int64
#  9   popularity    86275 non-null  float64
#  10  poster_url    85116 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 7.9+ MB

# %%
df1['cast'].head().to_list()
# Out:
# ["['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim Varney', 'Wallace Shawn']",
#  "['Robin Williams', 'Kirsten Dunst', 'Bradley Pierce', 'Bonnie Hunt', 'Jonathan Hyde']",
#  "['Walter Matthau', 'Jack Lemmon', 'Ann-Margret', 'Sophia Loren', 'Daryl Hannah']",
#  "['Whitney Houston', 'Angela Bassett', 'Loretta Devine', 'Lela Rochon', 'Gregory Hines']",
#  "['Steve Martin', 'Diane Keaton', 'Martin Short', 'Kimberly Williams-Paisley', 'George Newbern']"]

# %%
df2['cast'].head().to_list()
# Out:
# ['[{\'name\': \'Tom Hanks\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/eKF1sGJRrZJbfBG1KirPt1cfNd3.jpg\'}, {\'name\': \'Tim Allen\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/woWhZzFILVhYMAvsPL171HjMY0y.jpg\'}, {\'name\': \'Don Rickles\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/iJLQV4dcbTUgxlWJakjDldzlMXS.jpg\'}, {\'name\': \'Jim Varney\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/zvBFmvKUrPvE6FW35O3RP4i1ZPp.jpg\'}, {\'name\': \'Wallace Shawn\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/wVaM1WlFKDce4esThwL4XtNLhOe.jpg\'}, {\'name\': \'John Ratzenberger\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/oRtDEOuIO1yDhTz5dORBdxXuLMO.jpg\'}, {\'name\': \'Annie Potts\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/hWIzkAH7jkSkxBfwdudxbSPxeno.jpg\'}, {\'name\': \'John Morris\', \'profile_url\': \'https://image.tmdb.org/t/p/w500/lSdNMhN3DoXEQJ37IeOD5mTMUQK.jpg\'}, {\'name\': \'Erik von Detten\', \'profile_url\': \'https://image.tmdb.or
# ...

# %%
df2['poster_urls'].head().to_list()
# Out:
# ["['https://image.tmdb.org/t/p/w500/uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg', 'https://image.tmdb.org/t/p/w500/koUNJtRB1iRKhST9s4itGTzU6lp.jpg', 'https://image.tmdb.org/t/p/w500/q5b86mLRElrbRQf7JBixFZykOA6.jpg', 'https://image.tmdb.org/t/p/w500/1Lxqh5rFjMVMW4BUyGx4wIYQCYx.jpg', 'https://image.tmdb.org/t/p/w500/AptcisAVyZqBllXLEGje8MjKzJI.jpg', 'https://image.tmdb.org/t/p/w500/9Ijv9yyg32mlQbJDYbOoKlWlWbp.jpg', 'https://image.tmdb.org/t/p/w500/fiNp79LUmwhArIpJvbuK4D0LPec.jpg', 'https://image.tmdb.org/t/p/w500/6AafgfifXkFS4g2xGJZIwsPQK6P.jpg', 'https://image.tmdb.org/t/p/w500/bVqDDZlTGFB42ea5kBSEptOhrIO.jpg', 'https://image.tmdb.org/t/p/w500/v9Fr3uof92ZqHt4lLqPA9syK6oA.jpg', 'https://image.tmdb.org/t/p/w500/xkCKS3C7OnTrhMTP0QlISa11NSJ.jpg', 'https://image.tmdb.org/t/p/w500/ifauvhU2ilS3lVeqTi2eh2FUe3o.jpg', 'https://image.tmdb.org/t/p/w500/oLII3pJFSfeLFDKCZbaUIAXEqqz.jpg', 'https://image.tmdb.org/t/p/w500/pb8tdrqMIvFsQSDJoOZLaunIGXw.jpg', 'https://image.tmdb.org/t/p/w500/b5Lzdp4Ku2TzHCDCDNSXXdPa
# ...

# %%
df1=df1.drop(columns=['cast'])

# %%
df1.head()
# Out:
#    movie_id                        title  \
# 0       862                    Toy Story
# 1      8844                      Jumanji
# 2     15602             Grumpier Old Men
# 3     31357            Waiting to Exhale
# 4     11862  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                            genres  \
# 0  ['Family', 'Comedy', 'Animation', 'Adventure']
# 1              ['Adventure', 'Fantasy', 'Family']
# 2                           ['Romance', 'Comedy']
# 3                  ['Comedy', 'Drama', 'Romance']
# 4                            ['Comedy', 'Family']
#
#                                             keywords         director  \
# ...

# %%
df2.head()
# Out:
#    movie_id    budget    revenue  \
# 0       862  30000000  394436586
# 1      8844  65000000  262821940
# 2     15602  25000000   71500000
# 3     31357  16000000   81452156
# 4     11862         0   76594107
#
#                                              tagline  \
# 0    The adventure takes off when toys come to life!
# 1                             It's a jungle in here.
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just when his world is back to normal... he's ...
#
#                                          poster_urls  \
# 0  ['https://image.tmdb.org/t/p/w500/uXDfjJbdP4ij...
# 1  ['https://image.tmdb.org/t/p/w500/nLXYV4WmYUF4...
# 2  ['https://image.tmdb.org/t/p/w500/1FSXpj5e8l4K...
# 3  ['https://image.tmdb.org/t/p/w500/afLVNPUxvBZ5...
# 4  ['https://image.tmdb.org/t/p/w500/rj4LBtwQ0uGr...
#
#                                           video_keys  \
# 0  ['_hIfuYVgBrY', 'TZOCUtoygtc', 'CxwTLktovTU', ...
# ...

# %%
# we will merge on movie id column
merged_df = pd.merge(df1, df2, on='movie_id', how='inner', suffixes=('_left', '_right'))

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86273 entries, 0 to 86272
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       86273 non-null  int64
#  1   title          86273 non-null  object
#  2   overview       85989 non-null  object
#  3   genres         86273 non-null  object
#  4   keywords       86273 non-null  object
#  5   director       85745 non-null  object
#  6   release_date   86239 non-null  object
#  7   runtime        86273 non-null  int64
#  8   popularity     86273 non-null  float64
#  9   poster_url     85114 non-null  object
#  10  budget         86273 non-null  int64
#  11  revenue        86273 non-null  int64
#  12  tagline        41914 non-null  object
#  13  poster_urls    86273 non-null  object
#  14  video_keys     86273 non-null  object
#  15  review_texts   86273 non-null  object
#  16  external_ids   86273 non-null  object
# ...

# %%
merged_df.to_csv(r"C:\Users\alyah\VC\first_project\recommendation system\merged_movies.csv", index=False)

# %%
df3=pd.read_csv(r"C:\Users\alyah\VC\first_project\recommendation system\modern_movies_2024_2025.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9982 entries, 0 to 9981
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       9982 non-null   int64
#  1   title          9982 non-null   object
#  2   overview       9224 non-null   object
#  3   genres         9982 non-null   object
#  4   keywords       9982 non-null   object
#  5   director       9537 non-null   object
#  6   release_date   9982 non-null   object
#  7   runtime        9982 non-null   int64
#  8   popularity     9982 non-null   float64
#  9   poster_url     9754 non-null   object
#  10  budget         9982 non-null   int64
#  11  revenue        9982 non-null   int64
#  12  tagline        2760 non-null   object
#  13  poster_urls    9982 non-null   object
#  14  video_keys     9982 non-null   object
#  15  review_texts   9982 non-null   object
#  16  external_ids   9982 non-null   object
# ...

# %%
df3.duplicated().sum()
# Out:
# np.int64(754)

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
# we will append df3 to merged_df
final_df = pd.concat([merged_df, df3], ignore_index=True)

# %%
final_df.to_csv(r"C:\Users\alyah\VC\first_project\recommendation system\movies_DB.csv", index=False)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95501 entries, 0 to 95500
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       95501 non-null  int64
#  1   title          95501 non-null  object
#  2   overview       94513 non-null  object
#  3   genres         95501 non-null  object
#  4   keywords       95501 non-null  object
#  5   director       94556 non-null  object
#  6   release_date   95467 non-null  object
#  7   runtime        95501 non-null  int64
#  8   popularity     95501 non-null  float64
#  9   poster_url     94133 non-null  object
#  10  budget         95501 non-null  int64
#  11  revenue        95501 non-null  int64
#  12  tagline        44485 non-null  object
#  13  poster_urls    95501 non-null  object
#  14  video_keys     95501 non-null  object
#  15  review_texts   95501 non-null  object
#  16  external_ids   95501 non-null  object
# ...

# %%
final_df.head()
# Out:
#   movie_id                        title  \
# 0      862                    Toy Story
# 1     8844                      Jumanji
# 2    15602             Grumpier Old Men
# 3    31357            Waiting to Exhale
# 4    11862  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                            genres  \
# 0  ['Family', 'Comedy', 'Animation', 'Adventure']
# 1              ['Adventure', 'Fantasy', 'Family']
# 2                           ['Romance', 'Comedy']
# 3                  ['Comedy', 'Drama', 'Romance']
# 4                            ['Comedy', 'Family']
#
#                                             keywords         director  \
# ...

# %%
# now our final DB contains all the movies data merged from three different datasets with over 95,000 records.
# it contains old and modern movies 
# now we will clean and preprocess this data
